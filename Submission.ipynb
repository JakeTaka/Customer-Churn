# %% [markdown]
# # EDA for Customer Churn
#
# This is my ntoebook for my submission to the Kaggle Playground Customer Churn March 2026 competition. I am newer to these competitions so I am just going to start with some EDA today.
#
# My goals for this EDA are based off of the goals from kaggle grandmaster Chris Deotte.
#
# T.S Elliot said, _"Immature poets imitate; mature poets steal."_
#
# I doubt I'm good enough to steal yet so let's see how my attempt at imitation goes.
#
# The goals for the EDA section of this notebook are:
# - is column Categorical or Numeric
# - how many unique values per column
# - how many nan values per column
# - distribution of column values
# - relationship between column and target
# - distribution of target
#
# My thanks to Chris for publishing his EDA so others can learn from his experience.

# %% [markdown]
# ### Some preliminary matters

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
# 3            No     Fiber optic             No  ...               No
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# ### Goal: is column Categorical or Numeric?

# %%
data.dtypes
# Out:
# id                    int64
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                   str
# dtype: object

# %% [markdown]
# ### Goal: How many unique values per column?

# %%
for column in data.columns:a
    print(f"The {column.lower()} column has {len(data[column].value_counts())} unique values.")
# Out:
# The id column has 594194 unique values.
# The gender column has 2 unique values.
# The seniorcitizen column has 2 unique values.
# The partner column has 2 unique values.
# The dependents column has 2 unique values.
# The tenure column has 72 unique values.
# The phoneservice column has 2 unique values.
# The multiplelines column has 3 unique values.
# The internetservice column has 3 unique values.
# The onlinesecurity column has 3 unique values.
# The onlinebackup column has 3 unique values.
# The deviceprotection column has 3 unique values.
# The techsupport column has 3 unique values.
# The streamingtv column has 3 unique values.
# The streamingmovies column has 3 unique values.
# The contract column has 3 unique values.
# The paperlessbilling column has 2 unique values.
# The paymentmethod column has 4 unique values.
# The monthlycharges column has 1921 unique values.
# The totalcharges column has 31910 unique values.
# The churn column has 2 unique values.

# %%
len(data.id.value_counts())
# Out:
# 594194

# %% [markdown]
# Intuitively, I think this can help us get some insight into the first question as well. Maybe a more concise way to accomplish answering both of these questions in the future is something like the following:

# %%
for column in data.columns:
    unique_count = data[column].nunique()
    col_type = "categorical" if unique_count < 5 else "numeric"
    print(f"{column:<16} | unique: {unique_count:<6} | type: {col_type}")
# Out:
# id               | unique: 594194 | type: numeric
# gender           | unique: 2      | type: categorical
# SeniorCitizen    | unique: 2      | type: categorical
# Partner          | unique: 2      | type: categorical
# Dependents       | unique: 2      | type: categorical
# tenure           | unique: 72     | type: numeric
# PhoneService     | unique: 2      | type: categorical
# MultipleLines    | unique: 3      | type: categorical
# InternetService  | unique: 3      | type: categorical
# OnlineSecurity   | unique: 3      | type: categorical
# OnlineBackup     | unique: 3      | type: categorical
# DeviceProtection | unique: 3      | type: categorical
# TechSupport      | unique: 3      | type: categorical
# StreamingTV      | unique: 3      | type: categorical
# StreamingMovies  | unique: 3      | type: categorical
# Contract         | unique: 3      | type: categorical
# PaperlessBilling | unique: 2      | type: categorical
# PaymentMethod    | unique: 4      | type: categorical
# ...

# %% [markdown]
# The above for loop was reworked by chatgpt after I wrote something that physically hurt my eyes to read.
#
# I'll provide it here for your entertainment:
